# %%
from langchain_docling import DoclingLoader

loader = DoclingLoader(file_path="./data/raw/CUAD_v1/full_contract_pdf/Part_I/Affiliate_agreements/CreditcardscomInc_20070810_S-1_EX-10.33_362297_EX-10.33_Affiliate Agreement.pdf")
docs = loader.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain_docling import DoclingLoader
#       3 loader = DoclingLoader(file_path="./data/raw/CUAD_v1/full_contract_pdf/Part_I/Affiliate_agreements/CreditcardscomInc_20070810_S-1_EX-10.33_362297_EX-10.33_Affiliate Agreement.pdf")
#       4 docs = loader.load()
#
# ModuleNotFoundError: No module named 'langchain_docling'
